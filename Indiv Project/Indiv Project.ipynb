# %%
import csv

# %%
file = open('data.csv', 'rb')
reader = csv.reader(file)
index = 0
Percent_body_fat_from_Siris_1956_equation = []
Age = []
for row in reader:
    if index != 0:
        a = row[0]
        b = a.split()
        Percent_body_fat_from_Siris_1956_equation.append(b[1])
        Age.append(b[2])
        print b      
     
    index += 1
print ""
print "Percent_body_fat_from_Siris_1956_equation: ",
for String in Percent_body_fat_from_Siris_1956_equation:
    print String,
    
print ""

print""
print "Age: ",
for String in Age:
    print String,

file.close()
# Out:
# ['1.0853', '6.1', '22', '173.25', '72.25', '38.5', '93.6', '83.0', '98.7', '58.7', '37.3', '23.4', '30.5', '28.9', '18.2']
# ['1.0414', '25.3', '22', '154.00', '66.25', '34.0', '95.8', '87.9', '99.2', '59.6', '38.9', '24.0', '28.8', '25.2', '16.6']
# ['1.0751', '10.4', '26', '184.75', '72.25', '37.4', '101.8', '86.4', '101.2', '60.1', '37.3', '22.8', '32.4', '29.4', '18.2']
# ['1.0340', '28.7', '24', '184.25', '71.25', '34.4', '97.3', '100.0', '101.9', '63.2', '42.2', '24.0', '32.2', '27.7', '17.7']
# ['1.0502', '20.9', '24', '210.25', '74.75', '39.0', '104.5', '94.4', '107.8', '66.0', '42.0', '25.6', '35.7', '30.6', '18.8']
# ['1.0549', '19.2', '26', '181.00', '69.75', '36.4', '105.1', '90.7', '100.3', '58.4', '38.3', '22.9', '31.9', '27.8', '17.7']
# ['1.0704', '12.4', '25', '176.00', '72.50', '37.8', '99.6', '88.5', '97.1', '60.0', '39.4', '23.2', '30.5', '29.0', '18.8']
# ...

# %%
from pylab import *

# %%
figure = plt.figure()
Chart = figure.add_subplot(111)
Chart.set_title('Percent body fat VS Age')
Chart.set_xlabel('Age')
Chart.set_ylabel('Percent body fat')
Chart.scatter(Age, Percent_body_fat_from_Siris_1956_equation)
figure.savefig("Percent_body_fat_from_Siris_1956_equation_with_titles.png")

print ""
print ""
print "Dean Leitersdorf"
print ""
print "Introduction: The data set I am working with is body fat. It is from: http://lib.stat.cmu.edu/datasets/bodyfat ."
print "I want to check whether there is a relationship between the percentage of body fat, and age."
print ""
print ""
print "As clearly seen below, there is no substancial correlation between age and percentage of body fat."
# Out:
# Dean Leitersdorf
#
# Introduction: The data set I am working with is body fat. It is from: http://lib.stat.cmu.edu/datasets/bodyfat .
# I want to check whether there is a relationship between the percentage of body fat, and age.
#
#
# As clearly seen below, there is no substancial correlation between age and percentage of body fat.
